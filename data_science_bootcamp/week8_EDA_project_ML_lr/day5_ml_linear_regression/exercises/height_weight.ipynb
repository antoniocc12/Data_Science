# %% [markdown]
# ### Se pide, usando regresión lineal:
#
# Dibujar con una línea la relación que hay entre la altura (X) y la edad (y) de los alumnos de la clase:
#
# - ¿Es una buena técnica para este tipo de problemas? ¿Por qué?
# - ¿Qué error se comete? Calcula los errores que está cometiendo tu modelo uno a uno (lo tienes que calcular tú con python). Aparte, usa el MSE y el RMSE. ¿Alguno es mejor para este problema?
# - Representa la matriz de correlación, ¿los datos están correlacionados?
# - ¿Qué ocurre si la altura se multiplica por dos? ¿Y si se multiplica solo la edad?

# %%
lista_alumnos = [("Clara Piniella", 30, 1.66),("Daniel Walker", 34, 1.87), ("Leonardo Frazzetto", 31, 1.78),("Xinru Yang", 24, 1.60), ("Jorge Garcia", 28, 1.79), ("Jonathan Suárez", 27, 1.86),("Marina Serrano", 25, 1.54), ("Karina Inche", 30, 1.61), ("Mary Meza", 32, 1.52),("Borja Puig", 37, 1.82), ("Mauro Garcia-Oliva", 45, 1.77), ("José Carlos Batista", 28, 1.70),("Isabel Palomares",24,1.78),("Gina Garrido",57,1.63), ("Sonia Cobo", 29, 1.73), ("Miguel Barquero", 35, 1.85),("Nacho Astorga",47,1.78), ("Adrià Gallardo", 24, 1.70), ("Juan Bayon", 38, 1.64), ("Nacho Fontal", 35, 1.82), ("Pablo Eduardo", 29, 1.75), ("Javier Araiz", 32, 1.74) ]

# %%
altura = []
edad = []

for i in lista_alumnos:
    edad.append(i[1])
    altura.append(i[2])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing the Linear Regression Algorithm
from sklearn.linear_model import LinearRegression

# %%
X = altura
X = np.array(X).reshape(-1, 1)

# %%
y = edad
y = np.array(y).reshape(-1, 1)

# %%
lm = LinearRegression(n_jobs=-1)
lm.fit(X, y)
# Out:
# LinearRegression(n_jobs=-1)

# %%
plt.scatter(X, y, color='g')
plt.plot(X, lm.predict(X), color='red')

# %%
lm.score(X, y) * 100
# Out:
# 0.6353025059937178

# %%
lm.intercept_
# Out:
# array([21.65037467])

# %%
lm.coef_
# Out:
# array([[6.44944009]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
predictions = lm.predict(X_test)
#predictions

# %%
plt.scatter(y_test, predictions, edgecolor='black')

# %%
from sklearn import metrics
import seaborn as sns
import pandas as pd

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 6.677250147343608
# MSE: 71.4046264254496
# RMSE: 8.450125823054329

# %%
lm.score(X_train, y_train) * 100 # Entrenamiento
# Out:
# -4.136497621273305

# %%
lm.score(X_test, y_test) * 100  # Test
# Out:
# -27.144990073806262

# %%
lm.score(X, y) * 100  # Test
# Out:
# 0.6353025059937178

# %%
df = pd.DataFrame ({'altura': altura, 'edad': edad})
sns.heatmap(df.corr(), square=False)
plt.show()

# %% [markdown]
# ## RESULTALDOS :
# ### Considero que la regresión lineal si es una buena técnica para este tipo de problemas, ya que este método de machine learning permite estudiar las relaciones entre dos variables continuas cuantitativas como es el caso de la edad y la altura.
# ### El calculo de los errores como MSE y el RMSE muestran que el modelo no es bueno.
# ### La matriz de correlacion no muestree que los datos esten correlacionados.

# %% [markdown]
# ¿Qué ocurre si la altura se multiplica por dos?

# %%
edad = []
altura = []

# %%
for i in lista_alumnos:
    edad.append(i[1]*2)
    altura.append(i[2])

# %%
X = altura 
X = np.array(X).reshape(-1, 1)

# %%
y = edad
y = np.array(y).reshape(-1, 1)

# %%
lm = LinearRegression(n_jobs=-1)
lm.fit(X, y)
# Out:
# LinearRegression(n_jobs=-1)

# %%
plt.scatter(X, y, color='g')
plt.plot(X, lm.predict(X), color='red')

# %%
lm.score(X, y) * 100
# Out:
# 0.6353025059937178

# %%
lm.intercept_
# Out:
# array([43.30074935])

# %%
lm.coef_
# Out:
# array([[12.89888019]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
lm.score(X_train, y_train) *100
# Out:
# -4.136497621273305

# %%
lm.score(X_test, y_test) *100
# Out:
# -27.144990073806262

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test, predictions, edgecolor='black')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 41.4889029216132
# MSE: 1939.4549758402852
# RMSE: 44.03924358842106

# %%
df = pd.DataFrame ({'altura': altura, 'edad': edad})
sns.heatmap(df.corr(), square=False)
plt.show()

# %% [markdown]
# ¿Y si se multiplica solo la edad?

# %%
edad = []
altura = []

for i in lista_alumnos:
    edad.append(i[1])
    altura.append(i[2]*2)

# %%
X = altura 
X = np.array(X).reshape(-1, 1)

# %%
y = edad
y = np.array(y).reshape(-1, 1)

# %%
lm = LinearRegression(n_jobs=-1)
lm.fit(X, y)
# Out:
# LinearRegression(n_jobs=-1)

# %%
plt.scatter(X, y, color='g')
plt.plot(X, lm.predict(X), color='red')

# %%
lm.score(X, y) * 100
# Out:
# 0.6353025059937178

# %%
lm.intercept_
# Out:
# array([21.65037467])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
lm.coef_
# Out:
# array([[3.22472005]])

# %%
lm.score(X_train, y_train) *100
# Out:
# -4.136497621273305

# %%
lm.score(X_test, y_test) *100
# Out:
# -27.144990073806262

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test, predictions, edgecolor='black')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 6.677250147343608
# MSE: 71.4046264254496
# RMSE: 8.450125823054329

# %%
df = pd.DataFrame ({'altura': altura, 'edad': edad})
sns.heatmap(df.corr(), square=False)
plt.show()

# %% [markdown]
# ### RESULTALDOS :
# #### Si se multiplica por dos, tanto la altura como la edad, se observan los mismos resultados.
# #### Considero que la regresión lineal si es una buena técnica para este tipo de problemas, ya que este método de machine learning permite estudiar las relaciones entre dos variables continuas cuantitativas como es el caso de la edad y la altura.
# #### El calculo de los errores como MSE y el RMSE muestran que el modelo no es bueno.
# #### La matriz de correlacion no muestree que los datos esten correlacionados.
