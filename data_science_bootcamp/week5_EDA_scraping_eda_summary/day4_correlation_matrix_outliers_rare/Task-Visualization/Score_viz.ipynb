# %% [markdown]
# # Scores *

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np 
import requests
import seaborn
from matplotlib.pyplot import *
import matplotlib.pyplot as plt 
import scipy.stats as stats
import seaborn as sns
sns.set_context('notebook')
sns.set_style('darkgrid')
import scipy.stats as stats

# print the graphs in the notebook
% matplotlib inline

# remember to %matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ### Step 2. Create the DataFrame it should look like below.
#
# This time you will create the data.

# %%
data = {'first_name':  ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 'age': [42, 52, 36, 24, 73], 'female': [0, 1, 1, 0, 1], 'preTestScore': [4, 24, 31, 2, 3], 'postTestScore': [25, 94, 57, 62, 70]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %%
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
plt.scatter(df.preTestScore, df.postTestScore
, s=df.age)
plt.title('preTestScore x postTestScore') #title
plt.xlabel('postTestScore') #x label
plt.ylabel('preTestScore') #y label
# Out:
# Text(0, 0.5, 'preTestScore')

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.scatter(df.preTestScore, df.postTestScore
, s=df.postTestScore*4.5, c=df.female)
plt.title('preTestScore x postTestScore') #title
plt.xlabel('postTestScore') #x label
plt.ylabel('preTestScore') #y label
# Out:
# Text(0, 0.5, 'preTestScore')
