# %% [markdown]
# # Tips **

# %% [markdown]
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# print the graphs in the notebook
# %matplotlib inline

# set seaborn style to white
sns.set_style("white")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips['Unnamed: 0']

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
ttbill = sns.distplot(tips.total_bill)
ttbill.set(xlabel = 'Value', ylabel = 'Frequency', title = "Total Bill")
sns.despine()

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sns.jointplot(x ="total_bill", y ="tip", data = tips)

# %% [markdown]
# ### Step 7.  Create one image with the relationship of `total_bill`, `tip` and `size`.
# #### Hint: It is just one function.

# %%
sns.pairplot(tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
plt.figure(figsize = (7.5,6))
sns.stripplot(x = "day", y = "total_bill", data = tips)

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
plt.figure(figsize = (8,6))

my_pal = {"Female": "b", "Male": "g"}
sns.stripplot(x = "tip", y = "day", hue = "sex", data = tips, palette = my_pal)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
plt.figure(figsize = (8,6))

my_pal1 = {"Dinner": "b", "Lunch": "g"}
sns.boxplot(x = "day", y = "total_bill", hue = "time", data = tips, palette=my_pal1)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
sns.set(style = "ticks")

face = sns.FacetGrid(tips, col = "time")
face.map(plt.hist, "tip");

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
face1 = sns.FacetGrid(tips, col = "sex", hue = "smoker", palette = ['b','g'])
face1.map(plt.scatter, "total_bill", "tip", s = 15, alpha =.7)

face1.add_legend()
