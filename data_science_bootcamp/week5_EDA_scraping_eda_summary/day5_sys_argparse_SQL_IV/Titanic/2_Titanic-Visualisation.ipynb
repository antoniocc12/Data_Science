# %% [markdown]
#    #                                                  Titanic Exercise II
#    #### Practice matplotlib & seaborn

# %% [markdown]
# ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)

# %% [markdown]
# First of all, import the needed libraries.

# %%
# visualisation libraries
import pandas as pd
import numpy as np 
import requests
import seaborn
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
sns.set_context('notebook')
sns.set_style('darkgrid')
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# 1. Read the `.csv` file you generated in **1_Titanic-Pandas** `titanic_cleaned.csv` and call the variable `titanic`.
#
# Help: If you didn't get to the point in which you should have saved the file, ask the instructor.

# %%
filename = "titanic_cleaned.csv"

# %%
#your code
titanic = pd.read_csv(filename)

# %% [markdown]
# 2. Using matplotlib find the appropriate visualization to show the distribution of the column `age`

# %%
#your code here
plt.figure()
_ = titanic["age"].hist()
plt.title('Distribucion de Edades en el Titanic')
plt.xlabel('Edades')
plt.ylabel('Frecuencias')
# Out:
# Text(0, 0.5, 'Frecuencias')

# %% [markdown]
# 3. Now use seaborn to show the distribution of the column `age`.

# %%
#your code here
sns.distplot(titanic['age'], hist = True)
# Out:
# C:\Users\Mary\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# 4. Use subplots to plot the distribution of the Age variable with bins equal to 10, 20 and 50.
#
# Use `sns.histplot()` for that aim.

# %%
#your code here
bins = [10, 20, 50]
sns.histplot(data = titanic, x= 'age', bins=bins )
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# 5. Whether the bin size affects your plot? Why?

# %%
#your comment here
Esta distribucion se ve afectada por que dejan de mostrarse los valores con menor frecuencia.

# %% [markdown]
# 6. Using matplotlib find the appropriate plot to visualize the column `'gender'`

# %%
# your code here
fig, ax = plt.subplots()  
x = titanic.gender.unique()  
y = titanic.gender.value_counts()  
ax.bar(x, y)  
ax.set_xlabel('Gender')  
ax.set_ylabel('Count')  
plt.show()

# %% [markdown]
# 7. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?

# %%
#your code
sns.countplot(titanic.gender)  
plt.show()
# Out:
# C:\Users\Mary\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 6. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](img/catplot.png)

# %%
#your code
sns.catplot(x ='gender', y ='survived', kind="bar", data = titanic)

# %% [markdown]
# 7. Use the appropriate plot to visualize the column `pclass`.

# %%
#your code
sns.countplot(titanic.pclass)  
plt.show()
# Out:
# C:\Users\Mary\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 8. We would like to have in one single plot the summary statistics of the feature `age`. Choose the appropriate plot to show below.

# %%
sns.boxplot(x='age', data=titanic)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# 9. What does the previous plot tell you about the feature Age? Comment.

# %% [markdown]
# #### El gráfico anterior muestra como la mayor densidad de edad de los pasajeros del titanic estaba distriuida en el rango de 30 a 40 años, que corresponde al cuartl superior. La mediana esta ubicada por los 28 años aproximadamente. Existen ciertos valores atipicos entre los 66 y los 80 años. Y el rango inferior se situa en los 0 años.

# %% [markdown]
# 10. Now in addition to the summary statistics, we also want to visualize the distribution of `age`. Choose the appropriate plot to show below.

# %%
plt.figure(figsize=(20,5))
sns.violinplot(titanic['age'], color = 'green')
# Out:
# C:\Users\Mary\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# 11. Use the appropriate plot to display the distributions of `age` in relation to `gender`.
#
# Hint: use Facetgrid to display the distribution of age for each categorical value of gender.

# %%
g = sns.FacetGrid(titanic, col= 'gender')
g.map(sns.histplot, 'age')

# %% [markdown]
# 12. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](img/kdeplot.png)

# %%
#your code 
age_bins = np.arange(0, 100, 4)
sns.kdeplot(titanic.loc[(titanic['survived']==0) & (~titanic['age'].isnull()),'age' ], color='red', shade = True )
sns.kdeplot(titanic.loc[(titanic['survived']==1) & (~titanic['age'].isnull()),'age'], color='green', shade = True )
plt.title('Age distribution among survival classes')
plt.ylabel('Frequency')
plt.legend(['Not survive', 'Survived'])
plt.show()

# %% [markdown]
# 13. Using Seaborn plot the correlation matrix of various features.
#
# Hint: search how to use `heatmap`

# %%
c= titanic.corr()
c
# Out:
#             pclass  survived       age     sibsp     parch      fare
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629
# survived -0.312469  1.000000 -0.055512 -0.027825  0.082660  0.244265
# age      -0.408106 -0.055512  1.000000 -0.243699 -0.150917  0.178740
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539
# fare     -0.558629  0.244265  0.178740  0.160238  0.221539  1.000000

# %%
#your code here
sns.heatmap(c, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 14. According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# #### De acuerdo al gráfico anterior, se observa una relacion positiva entre los sobrevientes y la tarifa pagada. Así como entre la tarifa y el número de padres e hijos a bordo. Como es de esperarse, la relación entre el número de padres e hijos con el número de hermanos/conyuges a bordo, es positiva.
